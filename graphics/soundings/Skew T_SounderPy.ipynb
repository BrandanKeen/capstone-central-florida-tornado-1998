# %%
#Install this pip#
import sounderpy as spy

# get data | Note: any sounderpy data will work! "TBW is Tampa station", "year", "month", "day", "time 00z"
clean_data = spy.get_obs_data('TBW', '1998', '02', '23', '00')

# build the sounding!
spy.build_sounding(clean_data)
# Out:
# > OBSERVED DATA ACCESS FUNCTION --
# -----------------------------------
# > PROFILE FOUND: TBW on 02/23/1998 at 00z | From UW
# > COMPLETE --------
# > RUNTIME: 00:00:00
# > SUMMARY: 00Z Launch for KTBW, TAMPA BAY at 02-23-1998-00Z
#
# > THERMODYNAMICS ---------------------------------------------
# --- SBCAPE: 2891.6 | MUCAPE: 2891.6 | MLCAPE: 1038.2 | ECAPE: 2383.3
# --- MU 0-3: 287.4 | MU 0-6: 1161.8 | SB 0-3: 287.4 | SB 0-6: 1161.8
#
# > KINEMATICS -------------------------------------------------
# --- 0-500 SRW: 30.9 knot | 0-500 SWV: 0.033 | 0-500 SHEAR: 30.4 | 0-500 SRH: 211.7
# --- 1-3km SRW: 19.5 knot | 1-3km SWV: 0.003 | 1-3km SHEAR: 25.6 | | 1-3km SRH: 46.6
# ...
#
# > SOUNDING PLOTTER FUNCTION --
# ---------------------------------
# > COMPLETE --------
# > RUNTIME: 00:00:01
